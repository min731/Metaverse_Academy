# %% [markdown]
# # 도로 상황 분류 프로젝트

# %% [markdown]
# ### 영상 데이터를 통한 실시간 라벨링
# * 실전 Test 데이터
# * 맑은 날 주행 영상 or 비오는날 주행 영상 or 눈오는날 주행 영상이 주어졌을 때, frame별 예측!
# * 총 4500개  데이터, Normal(맑음) , Rainy(비), Snowy(눈) 각 1500개

# %% [markdown]
# ### 1. 영상 데이터 => 이미지 데이터
# ### 2. 이미지 데이터 => DataLoader
# ### 3. 모델 예측
# ### 4. 예측 결과 사진에 Labeling

# %%
import cv2
import os

print(cv2.__version__)
# Out:
# 4.8.0

# %%
def videoToImage(file_path):

    #'' 사이에 사용할 비디오 파일의 경로 및 이름을 넣어주도록 함
    video = cv2.VideoCapture(file_path)

    length = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
    width = int(video.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(video.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = video.get(cv2.CAP_PROP_FPS)

    print(file_path)
    print("length :", length)
    print("width :", width)
    print("height :", height)
    print("fps :", fps)
    # print('//'.join(file_path.split("//")[:-2])+'//images')

    save_path = '//'.join(file_path.split("//")[:-2])+'//images//'

    try:
        if not os.path.exists(save_path):
            os.makedirs(save_path)
            print(save_path)
    except OSError:
        print ('Error: Creating directory. ' +  save_path)

    count = 0

    while(video.isOpened()):
        
        # Normal, Rainy, Snowy 3개 클래스 각 5000개씩(영상 시간 고려)
        ret, image = video.read()

        # if(int(video.get(1)) % fps == 0): #앞서 불러온 fps 값을 사용하여 1초마다 추출
        if(int(video.get(1)) % 20 == 0): # 5 프레임당 1개씩 추출
            cv2.imwrite(save_path + "//frame%d.jpg" % count, image)
            print(save_path + "//frame%d.jpg" % count)
            # print('Saved frame number :', str(int(video.get(1))))
            count += 1

        if count > 5399:
            break
            
    video.release()

    return save_path

root_path = 'D://Weather conditions driving classification data (All)//video_test//origin_videos//'

save_path = videoToImage(root_path+'All_Classes(Video_Test_20min).mp4')
# Out:
# D://Weather conditions driving classification data (All)//video_test//origin_videos//All_Classes(Video_Test_20min).mp4
# length : 108565
# width : 1280
# height : 720
# fps : 30.0
# D://Weather conditions driving classification data (All)//video_test//images////frame0.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame1.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame2.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame3.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame4.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame5.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame6.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame7.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame8.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame9.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame10.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame11.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame12.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame13.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame14.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame15.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame16.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame17.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame18.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame19.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame20.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame21.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame22.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame23.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame24.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame25.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame26.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame27.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame28.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame29.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame30.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame31.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame32.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame33.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame34.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame35.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame36.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame37.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame38.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame39.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame40.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame41.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame42.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame43.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame44.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame45.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame46.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame47.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame48.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame49.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame50.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame51.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame52.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame53.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame54.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame55.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame56.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame57.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame58.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame59.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame60.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame61.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame62.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame63.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame64.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame65.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame66.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame67.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame68.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame69.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame70.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame71.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame72.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame73.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame74.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame75.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame76.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame77.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame78.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame79.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame80.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame81.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame82.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame83.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame84.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame85.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame86.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame87.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame88.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame89.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame90.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame91.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame92.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame93.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame94.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame95.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame96.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame97.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame98.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame99.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame100.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame101.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame102.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame103.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame104.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame105.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame106.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame107.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame108.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame109.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame110.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame111.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame112.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame113.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame114.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame115.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame116.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame117.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame118.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame119.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame120.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame121.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame122.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame123.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame124.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame125.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame126.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame127.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame128.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame129.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame130.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame131.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame132.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame133.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame134.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame135.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame136.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame137.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame138.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame139.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame140.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame141.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame142.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame143.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame144.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame145.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame146.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame147.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame148.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame149.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame150.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame151.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame152.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame153.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame154.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame155.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame156.jpg
# D://Weather conditions driving classification data (All)//video_test//images////frame157.jpg
# D://Weather conditions driving classification data (All)//video_test//images////fr
jpg',
#  'D://Weather conditions driving classification data (All)//video_test//images\\frame1893.jpg',
#  'D://Weather conditions driving classification data (All)//video_test//images\\frame1894.jpg',
#  'D://Weather conditions driving classification data (All)//video_test//images\\frame1895.jpg',
#  'D://Weather conditions driving classification data (All)//video_test//images\\frame1896.jpg',
#  'D://Weather conditions driving classification data (All)//video_test//images\\frame1897.jpg',
#  'D://Weather conditions driving classification data (All)//video_test//images\\frame1898.jpg',
#  ...]

# %% [markdown]
# ### transform 정의

# %%
# 가로로 절반으로 자르는 함수 정의
def crop_horizontal_half(img):
    width, height = img.size
    cropped_img = img.crop((0, height//2, width,height))

    return cropped_img

# %%
from torchvision import transforms
import torchvision


transform= transforms.Compose(
    [   
        transforms.Lambda(crop_horizontal_half),
        transforms.Resize((224,224)),
        transforms.ToTensor(),
        # transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225])

    ]
)

# %% [markdown]
# ### DataLoader 정의

# %%
from torch.utils.data import Dataset
from torchvision.transforms import ToTensor
import PIL

class ImageDataset(Dataset):
    def __init__(self, image_paths, transform=None):
        self.image_paths = image_paths
        self.transform = transform

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image_path = self.image_paths[idx]
        image = self.load_image(image_path)

        if self.transform:
            image = self.transform(image)

        return image

    def load_image(self, image_path):
        # 이미지 로드 로직을 구현합니다.
        # 예시로는 PIL 이미지를 사용하고, 필요에 따라 다른 라이브러리를 사용하셔도 됩니다.
        # 필요에 따라 이미지 크기 조정, 채널 변환 등의 로직을 추가할 수 있습니다.
        return PIL.Image.open(image_path).convert("RGB")

# %%
from torch.utils.data import DataLoader

# 이미지 파일 경로 리스트를 가정하고 시작합니다.
image_paths = images  # 이미지 파일 경로 리스트를 로드하세요.

# 데이터셋을 생성합니다.
dataset = ImageDataset(image_paths, transform=transform)

# DataLoader를 생성합니다.
dataloader = DataLoader(dataset, batch_size=32, shuffle=False)
dataloader

# %%
img = next(iter(dataloader))
img
# Out:
# tensor([[[[0.2078, 0.2353, 0.2392,  ..., 0.2431, 0.1765, 0.2078],
#           [0.2000, 0.1882, 0.1804,  ..., 0.2510, 0.2314, 0.3647],
#           [0.1882, 0.1647, 0.1373,  ..., 0.2549, 0.3137, 0.4549],
#           ...,
#           [0.4549, 0.4549, 0.4510,  ..., 0.4000, 0.4196, 0.4235],
#           [0.4588, 0.4549, 0.4549,  ..., 0.3882, 0.4000, 0.4196],
#           [0.4784, 0.4941, 0.5294,  ..., 0.4118, 0.3765, 0.4196]],
#
#          [[0.2667, 0.2941, 0.3020,  ..., 0.2706, 0.1882, 0.2235],
#           [0.2588, 0.2471, 0.2392,  ..., 0.2745, 0.2431, 0.3804],
#           [0.2471, 0.2235, 0.1961,  ..., 0.2784, 0.3294, 0.4745],
#           ...,
#           [0.5020, 0.5020, 0.4980,  ..., 0.4353, 0.4667, 0.4706],
#           [0.5059, 0.5020, 0.5020,  ..., 0.4235, 0.4510, 0.4706],
#           [0.5255, 0.5412, 0.5765,  ..., 0.4431, 0.4275, 0.4706]],
#
#          [[0.1765, 0.2039, 0.1961,  ..., 0.1765, 0.1059, 0.1529],
#           [0.1725, 0.1608, 0.1412,  ..., 0.1804, 0.1608, 0.3020],
#           [0.1686, 0.1373, 0.1020,  ..., 0.1882, 0.2471, 0.3961],
#           ...,
#           [0.5020, 0.5020, 0.4980,  ..., 0.4118, 0.4235, 0.4235],
#           [0.5059, 0.5020, 0.5020,  ..., 0.3961, 0.4039, 0.4235],
#           [0.5255, 0.5412, 0.5765,  ..., 0.4196, 0.3804, 0.4196]]],
#
#
#         [[[0.2510, 0.2863, 0.3961,  ..., 0.1882, 0.1725, 0.1765],
#           [0.2353, 0.2627, 0.3412,  ..., 0.1961, 0.1804, 0.1765],
#           [0.2510, 0.2549, 0.3255,  ..., 0.1922, 0.1843, 0.1765],
#           ...,
#           [0.4627, 0.4549, 0.4471,  ..., 0.4196, 0.4314, 0.4431],
#           [0.4588, 0.4431, 0.4353,  ..., 0.4039, 0.4235, 0.4314],
#           [0.4706, 0.4706, 0.4863,  ..., 0.3961, 0.3922, 0.4275]],
#
#          [[0.2824, 0.3020, 0.4039,  ..., 0.2118, 0.1961, 0.2000],
#           [0.2549, 0.2784, 0.3529,  ..., 0.2196, 0.2039, 0.2000],
#           [0.2706, 0.2745, 0.3412,  ..., 0.2196, 0.2078, 0.2000],
#           ...,
#           [0.5098, 0.4980, 0.4902,  ..., 0.4431, 0.4588, 0.4745],
#           [0.5059, 0.4863, 0.4745,  ..., 0.4275, 0.4549, 0.4745],
#           [0.5176, 0.5137, 0.5294,  ..., 0.4196, 0.4314, 0.4784]],
#
#          [[0.2392, 0.2627, 0.3608,  ..., 0.1961, 0.1804, 0.1843],
#           [0.2235, 0.2510, 0.3137,  ..., 0.2039, 0.1882, 0.1843],
#           [0.2431, 0.2471, 0.3098,  ..., 0.2039, 0.1922, 0.1843],
#           ...,
#           [0.5098, 0.4941, 0.4863,  ..., 0.4275, 0.4314, 0.4353],
#           [0.5059, 0.4824, 0.4706,  ..., 0.4118, 0.4275, 0.4353],
#           [0.5176, 0.5098, 0.5255,  ..., 0.4078, 0.4039, 0.4353]]],
#
#
#         [[[0.3804, 0.3804, 0.3647,  ..., 0.3176, 0.3333, 0.3804],
#           [0.3765, 0.3765, 0.3608,  ..., 0.3255, 0.2745, 0.4314],
#           [0.3765, 0.3725, 0.3608,  ..., 0.3725, 0.2314, 0.3294],
#           ...,
#           [0.4196, 0.4196, 0.4196,  ..., 0.4039, 0.4549, 0.4824],
#           [0.4235, 0.4157, 0.4353,  ..., 0.3765, 0.4353, 0.4745],
#           [0.4627, 0.4667, 0.4980,  ..., 0.3922, 0.3686, 0.4431]],
#
#          [[0.4588, 0.4588, 0.4431,  ..., 0.3529, 0.3686, 0.4196],
#           [0.4549, 0.4549, 0.4392,  ..., 0.3569, 0.3098, 0.4706],
#           [0.4549, 0.4510, 0.4392,  ..., 0.4039, 0.2667, 0.3647],
#           ...,
#           [0.4902, 0.4824, 0.4706,  ..., 0.4549, 0.4824, 0.4980],
#           [0.4941, 0.4824, 0.4902,  ..., 0.4275, 0.4667, 0.4941],
#           [0.5333, 0.5373, 0.5569,  ..., 0.4471, 0.4000, 0.4627]],
#
#          [[0.4941, 0.4941, 0.4745,  ..., 0.2510, 0.2471, 0.2824],
#           [0.4902, 0.4902, 0.4745,  ..., 0.2588, 0.1922, 0.3412],
#           [0.4902, 0.4863, 0.4745,  ..., 0.3098, 0.1569, 0.2431],
#           ...,
#           [0.4902, 0.4824, 0.4745,  ..., 0.4471, 0.4863, 0.4980],
#           [0.4941, 0.4863, 0.4941,  ..., 0.4275, 0.4745, 0.5059],
#           [0.5333, 0.5412, 0.5608,  ..., 0.4431, 0.4118, 0.4784]]],
#
#
#         ...,
#
#
#         [[[0.3059, 0.3098, 0.3569,  ..., 0.6275, 0.6314, 0.6314],
#           [0.2706, 0.3216, 0.3020,  ..., 0.6275, 0.6353, 0.6353],
#           [0.1333, 0.2510, 0.2157,  ..., 0.6314, 0.6392, 0.6392],
#           ...,
#           [0.4118, 0.4078, 0.4118,  ..., 0.3647, 0.3725, 0.3490],
#           [0.4353, 0.4275, 0.4275,  ..., 0.3137, 0.3686, 0.3529],
#           [0.4431, 0.4392, 0.4431,  ..., 0.2902, 0.3176, 0.3882]],
#
#          [[0.3412, 0.3451, 0.3882,  ..., 0.6863, 0.6902, 0.6902],
#           [0.3059, 0.3529, 0.3333,  ..., 0.6863, 0.6941, 0.6941],
#           [0.1686, 0.2824, 0.2471,  ..., 0.6863, 0.6980, 0.6980],
#           ...,
#           [0.4588, 0.4549, 0.4588,  ..., 0.4157, 0.4157, 0.3961],
#           [0.4824, 0.4745, 0.4745,  ..., 0.3647, 0.4196, 0.4078],
#           [0.4902, 0.4863, 0.4902,  ..., 0.3451, 0.3686, 0.4471]],
#
#          [[0.2706, 0.2784, 0.3333,  ..., 0.7098, 0.7098, 0.7098],
#           [0.2353, 0.2902, 0.2824,  ..., 0.7137, 0.7137, 0.7137],
#           [0.1020, 0.2235, 0.1961,  ..., 0.7176, 0.7176, 0.7176],
#           ...,
#           [0.4431, 0.4392, 0.4431,  ..., 0.4196, 0.4235, 0.3961],
#           [0.4667, 0.4588, 0.4588,  ..., 0.3725, 0.4314, 0.4196],
#           [0.4745, 0.4706, 0.4745,  ..., 0.3569, 0.3922, 0.4667]]],
#
#
#         [[[0.2549, 0.2235, 0.0784,  ..., 0.6275, 0.6275, 0.6275],
#           [0.2392, 0.2078, 0.0863,  ..., 0.6353, 0.6353, 0.6353],
#           [0.1922, 0.1569, 0.0863,  ..., 0.6353, 0.6353, 0.6353],
#           ...,
#           [0.4078, 0.4078, 0.4039,  ..., 0.3529, 0.3608, 0.3451],
#           [0.4353, 0.4353, 0.4314,  ..., 0.3137, 0.3647, 0.3569],
#           [0.4471, 0.4510, 0.4431,  ..., 0.2941, 0.3176, 0.3922]],
#
#          [[0.3059, 0.2667, 0.1216,  ..., 0.6863, 0.6863, 0.6863],
#           [0.2902, 0.2510, 0.1294,  ..., 0.6941, 0.6941, 0.6941],
#           [0.2392, 0.2000, 0.1255,  ..., 0.6941, 0.6941, 0.6941],
#           ...,
#           [0.4549, 0.4549, 0.4549,  ..., 0.4039, 0.4078, 0.3922],
#           [0.4824, 0.4824, 0.4784,  ..., 0.3686, 0.4196, 0.4118],
#           [0.4941, 0.4980, 0.4941,  ..., 0.3490, 0.3686, 0.4510]],
#
#          [[0.2392, 0.2118, 0.0745,  ..., 0.6980, 0.6980, 0.7020],
#           [0.2275, 0.2039, 0.0863,  ..., 0.6980, 0.6980, 0.6980],
#           [0.1843, 0.1569, 0.0941,  ..., 0.6980, 0.7020, 0.7020],
#           ...,
#           [0.4392, 0.4392, 0.4392,  ..., 0.4078, 0.4118, 0.3922],
#           [0.4667, 0.4667, 0.4627,  ..., 0.3725, 0.4314, 0.4196],
#           [0.4784, 0.4824, 0.4784,  ..., 0.3569, 0.3922, 0.4706]]],
#
#
#         [[[0.1922, 0.2471, 0.3020,  ..., 0.2314, 0.1686, 0.1608],
#           [0.2353, 0.2588, 0.2824,  ..., 0.2549, 0.2000, 0.2000],
#           [0.2353, 0.2706, 0.3333,  ..., 0.1961, 0.2039, 0.2510],
#           ...,
#           [0.4118, 0.4078, 0.4000,  ..., 0.3647, 0.3490, 0.3294],
#           [0.4275, 0.4275, 0.4235,  ..., 0.3255, 0.3569, 0.3255],
#           [0.4353, 0.4392, 0.4392,  ..., 0.2745, 0.3294, 0.3608]],
#
#          [[0.1882, 0.2431, 0.2941,  ..., 0.2863, 0.2235, 0.2157],
#           [0.2314, 0.2549, 0.2706,  ..., 0.3098, 0.2549, 0.2549],
#           [0.2314, 0.2667, 0.3176,  ..., 0.2510, 0.2588, 0.3059],
#           ...,
#           [0.4588, 0.4549, 0.4471,  ..., 0.4118, 0.3922, 0.3765],
#           [0.4745, 0.4745, 0.4706,  ..., 0.3804, 0.4039, 0.3765],
#           [0.4824, 0.4863, 0.4863,  ..., 0.3294, 0.3804, 0.4196]],
#
#          [[0.1216, 0.1765, 0.2118,  ..., 0.1843, 0.1255, 0.1176],
#           [0.1608, 0.1843, 0.1922,  ..., 0.2157, 0.1569, 0.1569],
#           [0.1608, 0.1961, 0.2392,  ..., 0.1608, 0.1608, 0.2078],
#           ...,
#           [0.4431, 0.4392, 0.4314,  ..., 0.4157, 0.3961, 0.3765],
#           [0.4588, 0.4588, 0.4549,  ..., 0.3882, 0.4157, 0.3882],
#           [0.4667, 0.4706, 0.4706,  ..., 0.3412, 0.4078, 0.4392]]]])

# %% [markdown]
# ### 모델 로드

# %%
import torch
import torch.nn as nn

weight_path = 'C://backend_study//metaverse_academy//03.딥러닝//개인프로젝트//(유튜브)기상 상황 주행 분류 프로젝트//models//resnet34(video_test).pt'

model = torchvision.models.resnet34(pretrained=True)
for param in model.parameters():
  # param.requires_grad = False == > 전부 동결
  param.requires_grad = True
fc_input_features = model.fc.in_features
model.fc = nn.Linear(fc_input_features,3)

model.load_state_dict(torch.load(weight_path))
model
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (5): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=3, bias=True)
# )

# %% [markdown]
# ### 이미지 데이터 검증 => PIL image에 예측 클래스 라벨링

# %%
from tqdm import tqdm
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image, ImageFont, ImageDraw
from matplotlib import cm

device = 'cuda' if torch.cuda.is_available() else 'cpu'

model.to(device)
model.eval()
class_names = ['Normal','Rainy','Snowy']

labeled_images_path = 'D://Weather conditions driving classification data (All)//video_test//labeled_images//'
# font = ImageFont.truetype("/usr/share/fonts/dejavu/DejaVuSans.ttf", 25)

font_size = 40
font = ImageFont.truetype("arial.ttf", font_size)


cnt = 0
with torch.no_grad():
  for data in tqdm(dataloader):
    preds = model(data.to(device))
    pred = torch.max(preds,1)[1]

    for i in range(32):

      try :
        img = np.array(data[i])
        img = (img * 255).astype(np.uint8)
        img = np.transpose(img,(1,2,0))
        pil_image=Image.fromarray(img)
        draw = ImageDraw.Draw(pil_image)
        draw.text(xy=(65,50), text=class_names[pred[i]], fill= (255,255,255),font=font)
        # print(labeled_images_path+'frame'+str(cnt)+'.jpg')
        pil_image.save(labeled_images_path+'frame'+str(cnt)+'.jpg')
        cnt += 1

      # 마지막 배치사이즈 안맞음
      except:
        pass
# Out:
# 100%|██████████| 169/169 [01:08<00:00,  2.48it/s]

# %% [markdown]
# ### 예시

# %% [markdown]
# ![frame4857.jpg](attachment:frame4857.jpg) ![frame4852.jpg](attachment:frame4852.jpg) ![frame2162.jpg](attachment:frame2162.jpg) ![frame5068.jpg](attachment:frame5068.jpg) ![frame4655.jpg](attachment:frame4655.jpg) ![frame2185.jpg](attachment:frame2185.jpg)
