# %% [markdown]
# # 차선검출
# ### 블랙박스 시점을 기반으로 탑뷰의 시점에서 차선을 검출하여 다시 블랙박스 시점으로 차선을 검출함
# ### 야간, 눈,비가 올때는 차선검출이 잘 안될 수 있음

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
road_img = cv2.imread('/content/drive/MyDrive/메타버스_아카데미_2기/딥러닝/7월/data/road1.jpg')
road_img = cv2.cvtColor(road_img,cv2.COLOR_BRG2RGB)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-a6b7446f59f3> in <cell line: 2>()
#       1 road_img = cv2.imread('/content/drive/MyDrive/메타버스_아카데미_2기/딥러닝/7월/data/road1.jpg')
# ----> 2 road_img = cv2.cvtColor(road_img,cv2.COLOR_BRG2RGB)
#
# AttributeError: module 'cv2' has no attribute 'COLOR_BRG2RGB'

# %%
road_blur = cv2.GaussianBlur()

# %% [markdown]
# ### 차선부분만 뽑아내기 위해 Masking 함

# %%
# 원본 이미지, Mask 이미지 똑같아야함

# %%
# cv2.fillPoly(mask.point,255) : 색상값을 채움
# bitwise : 원본 이미지와 마스크 이미지값이 흰색으로 동일한 부분만 차

# %%
# 1. 블러
# 2. Canny
# 3. 마스킹
# 4. Hough
