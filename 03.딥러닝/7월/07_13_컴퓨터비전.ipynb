# %% [markdown]
# # 컴퓨터비전

# %%
# 연구 파트
# 화질 개선
# 객체 검출
# 객체 인식

# 응용
# 머신 비전 : 공장,불량품 검사
# AI 서비스 : 배경과 객체 인식
# 화상채팅 배경 blur 처리
# 자율주행 : 객체검출, 차선 검출(차선에서 얼마나 벗어나는지 체크)

# %%
# 영상이란?
# pixel을 격자에 2차원 행렬로 나타내어 만든 형태

# pixel: 영상을 구성하는 최소 돤위
# ==화소

# 영상 파일 형식
# JPG : 손실 압축 기법 사용
# PNG : GIF를 대체하기 위한 오픈 소스 파일 포맷
# GIF : 그래픽 포맷, 색상의 무손실 압축 기술
# BMP : MS에서 개발, 비트맵 이미지를 저장하는 Window 그래픽 파일 형
