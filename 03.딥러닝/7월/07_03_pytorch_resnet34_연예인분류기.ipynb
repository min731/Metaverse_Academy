파일 다운로드가 완료되었습니다.
# ===============================================
# [Info] Done. Downloaded 50 images.

# %%
# 수집한 이미지를 학습 데이터 평가 데이터로 구분하는 함수

def dataset_split(query,train_cnt):

  for dir in directory_list:
    if not os.path.isdir(dir+'/'+query):
      os.makedirs(dir+query)

  cnt = 0
  # query에 해당하는 파일 가져오기
  for file_name in os.listdir(query):
      if cnt < train_cnt:
          print(f'trainset : {file_name}')
          shutil.move(query+'/'+file_name,'./dataset/train/'+query+'/'+file_name)
      else:
          print(f'testset : {file_name}')
          shutil.move(query+'/'+file_name,'./dataset/test/'+query+'/'+file_name)

      cnt += 1

# %%
# '마동석'을 40개 train으로 쓰겠다
dataset_split('마동석',40)
# Out:
# trainset : image_36.jpg
# trainset : image_1.jpg
# trainset : image_11.jpg
# trainset : image_41.jpg
# trainset : image_10.jpg
# trainset : image_7.jpg
# trainset : image_18.jpg
# trainset : image_12.jpg
# trainset : image_22.jpg
# trainset : image_27.jpg
# trainset : image_45.jpg
# trainset : image_4.jpg
# trainset : image_33.jpg
# trainset : image_34.jpg
# trainset : image_32.jpg
# trainset : image_43.jpg
# trainset : image_40.jpg
# trainset : image_20.png
# trainset : image_24.jpg
# trainset : image_29.jpg
# trainset : image_39.jpg
# trainset : image_19.jpg
# trainset : image_21.jpg
# trainset : image_35.jpg
# trainset : image_49.jpg
# trainset : image_5.jpg
# trainset : image_3.jpg
# trainset : image_9.jpg
# trainset : image_46.jpg
# trainset : image_38.jpg
# trainset : image_8.jpg
# trainset : image_28.jpg
# trainset : image_13.jpg
# trainset : image_50.JPG
# trainset : image_6.jpg
# trainset : image_15.jpg
# trainset : image_42.jpg
# trainset : image_16.jpg
# trainset : image_17.JPG
# trainset : image_26.JPG
# testset : image_37.jpg
# testset : image_14.jpg
# testset : image_23.jpg
# testset : image_48.jpg
# testset : image_47.jpg
# testset : image_31.jpg
# testset : image_30.jpg
# testset : image_25.jpg
# testset : image_44.jpg
# testset : image_2.jpg

# %%
dataset_split('카리나',40)
dataset_split('이국주',40)
# Out:
# trainset : image_36.jpg
# trainset : image_1.jpg
# trainset : image_25.jpeg
# trainset : image_41.jpg
# trainset : image_17.jpg
# trainset : image_7.jpg
# trainset : image_18.jpg
# trainset : image_12.jpg
# trainset : image_33.JPG
# trainset : image_22.jpg
# trainset : image_27.jpg
# trainset : image_45.jpg
# trainset : image_4.jpg
# trainset : image_34.jpg
# trainset : image_32.jpg
# trainset : image_40.jpg
# trainset : image_20.png
# trainset : image_24.jpg
# trainset : image_46.gif
# trainset : image_44.jpeg
# trainset : image_5.png
# trainset : image_38.png
# trainset : image_39.jpg
# trainset : image_19.jpg
# trainset : image_21.jpg
# trainset : image_43.JPG
# trainset : image_50.jpg
# trainset : image_26.jpg
# trainset : image_35.jpg
# trainset : image_49.jpg
# trainset : image_3.jpg
# trainset : image_9.jpg
# trainset : image_10.JPG
# trainset : image_8.jpg
# trainset : image_28.jpg
# trainset : image_11.jpeg
# trainset : image_6.jpg
# trainset : image_15.jpg
# trainset : image_42.jpg
# trainset : image_16.jpg
# testset : image_29.jpeg
# testset : image_37.jpg
# testset : image_14.jpg
# testset : image_23.jpg
# testset : image_48.jpg
# testset : image_47.jpg
# testset : image_31.jpg
# testset : image_30.jpg
# testset : image_13.gif
# testset : image_2.jpg
# trainset : image_36.jpg
# trainset : image_1.jpg
# trainset : image_11.jpg
# trainset : image_41.jpg
# trainset : image_10.jpg
# trainset : image_17.jpg
# trainset : image_7.jpg
# trainset : image_18.jpg
# trainset : image_12.jpg
# trainset : image_22.jpg
# trainset : image_27.jpg
# trainset : image_45.jpg
# trainset : image_4.jpg
# trainset : image_33.jpg
# trainset : image_34.jpg
# trainset : image_32.jpg
# trainset : image_20.jpg
# trainset : image_43.jpg
# trainset : image_40.jpg
# trainset : image_24.png
# trainset : image_29.jpg
# trainset : image_39.jpg
# trainset : image_19.jpg
# trainset : image_21.jpg
# trainset : image_50.jpg
# trainset : image_26.jpg
# trainset : image_35.jpg
# trainset : image_49.jpg
# trainset : image_5.jpg
# trainset : image_3.jpg
# trainset : image_9.jpg
# trainset : image_46.jpg
# trainset : image_38.jpg
# trainset : image_8.jpg
# trainset : image_28.jpg
# trainset : image_13.jpg
# trainset : image_6.jpg
# trainset : image_15.jpg
# trainset : image_42.jpg
# trainset : image_16.jpg
# testset : image_37.jpg
# testset : image_14.jpg
# testset : image_23.jpg
# testset : image_48.jpg
# testset : image_47.jpg
# testset : image_31.jpg
# testset : image_30.jpg
# testset : image_25.jpg
# testset : image_44.jpg
# testset : image_2.jpg

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
from torchvision import datasets,models,transforms
import numpy as np
import time

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %%
transform_train = transforms.Compose(

     [
        transforms.Resize((224,224)),
        transforms.RandomHorizontalFlip(p=0.5),
        transforms.ToTensor(),
        transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225])
    ]

)

transform_test = transforms.Compose(

     [
        transforms.Resize((224,224)),
        # transforms.RandomHorizontalFlip(p=0.5),
        transforms.ToTensor(),
        transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225])
    ]

)

# %% [markdown]
# ### train/ test 데이터

# %%
# 폴더 경로로 train,test 데이터 설정
train_datasets = datasets.ImageFolder('./dataset/train',transform=transform_train)
test_datasets = datasets.ImageFolder('./dataset/test',transform=transform_test)

# %%
train_datasets.classes
# Out:
# ['마동석', '이국주', '카리나']

# %% [markdown]
# ### train / test 데이터로더

# %%
train_loader = torch.utils.data.DataLoader(train_datasets,shuffle=True,batch_size=4)
test_loader = torch.utils.data.DataLoader(test_datasets,shuffle=True,batch_size=4)

# %%
len(train_datasets) , len(test_datasets)
# Out:
# (119, 29)

# %%
def imshow(img,title):

  # transform에서 tensor로 바꾸었기때문에 numpy()화
  print(img.numpy().shape)
  # c,w,h => w,h,c 변환
  img = img.numpy().transpose((1,2,0))
  print("shape : ",img.shape)
  std = np.array([0.229,0.224,0.225])
  mean = np.array([0.485,0.456,0.406])

  img = std*img+mean
  # print("clip 전 : ",img)
  img = np.clip(img,0,1)
  # print("clip 후 : ",img)

  plt.imshow(img)
  plt.title(title)
  plt.show()

# %%
class_names = train_datasets.classes
class_names
# Out:
# ['마동석', '이국주', '카리나']

# %%
iter_ = iter(train_loader)

data, labels = next(iter_)
# 배치 갯수만큼 나오기 때문에 make_grid() 사용
print("data shape : " ,data.shape)
print("data type : ",type(data))
out = torchvision.utils.make_grid(data)
print("out type : ",type(out))
print("out shape : ", out.shape)
imshow(out,title=[class_names[i] for i in labels])
# Out:
# data shape :  torch.Size([4, 3, 224, 224])
# data type :  <class 'torch.Tensor'>
# out type :  <class 'torch.Tensor'>
# out shape :  torch.Size([3, 228, 906])
# (3, 228, 906)
# shape :  (228, 906, 3)

# %%
# 일단 resnet34의 가중치를 가져옴
model = torchvision.models.resnet34(pretrained=True)
model
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (5): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# )

# %%
# (fc): Linear(in_features=512, out_features=1000, bias=True)
# out_features = 3로 변환

for param in model.parameters():
  # param.requires_grad = False == > 전부 동결
  param.requires_grad = False

# %%
fc_input_features = model.fc.in_features
fc_input_features
# Out:
# 512

# %%
# 마지막 분류기만 수정
model.fc = nn.Linear(fc_input_features,3)

for name,module in model.named_parameters():
  print("name : ",name," module.requres_grad : ", module.requires_grad)
# Out:
# name :  conv1.weight  module.requres_grad :  False
# name :  bn1.weight  module.requres_grad :  False
# name :  bn1.bias  module.requres_grad :  False
# name :  layer1.0.conv1.weight  module.requres_grad :  False
# name :  layer1.0.bn1.weight  module.requres_grad :  False
# name :  layer1.0.bn1.bias  module.requres_grad :  False
# name :  layer1.0.conv2.weight  module.requres_grad :  False
# name :  layer1.0.bn2.weight  module.requres_grad :  False
# name :  layer1.0.bn2.bias  module.requres_grad :  False
# name :  layer1.1.conv1.weight  module.requres_grad :  False
# name :  layer1.1.bn1.weight  module.requres_grad :  False
# name :  layer1.1.bn1.bias  module.requres_grad :  False
# name :  layer1.1.conv2.weight  module.requres_grad :  False
# name :  layer1.1.bn2.weight  module.requres_grad :  False
# name :  layer1.1.bn2.bias  module.requres_grad :  False
# name :  layer1.2.conv1.weight  module.requres_grad :  False
# name :  layer1.2.bn1.weight  module.requres_grad :  False
# name :  layer1.2.bn1.bias  module.requres_grad :  False
# name :  layer1.2.conv2.weight  module.requres_grad :  False
# name :  layer1.2.bn2.weight  module.requres_grad :  False
# name :  layer1.2.bn2.bias  module.requres_grad :  False
# name :  layer2.0.conv1.weight  module.requres_grad :  False
# name :  layer2.0.bn1.weight  module.requres_grad :  False
# name :  layer2.0.bn1.bias  module.requres_grad :  False
# name :  layer2.0.conv2.weight  module.requres_grad :  False
# name :  layer2.0.bn2.weight  module.requres_grad :  False
# name :  layer2.0.bn2.bias  module.requres_grad :  False
# name :  layer2.0.downsample.0.weight  module.requres_grad :  False
# name :  layer2.0.downsample.1.weight  module.requres_grad :  False
# name :  layer2.0.downsample.1.bias  module.requres_grad :  False
# name :  layer2.1.conv1.weight  module.requres_grad :  False
# name :  layer2.1.bn1.weight  module.requres_grad :  False
# name :  layer2.1.bn1.bias  module.requres_grad :  False
# name :  layer2.1.conv2.weight  module.requres_grad :  False
# name :  layer2.1.bn2.weight  module.requres_grad :  False
# name :  layer2.1.bn2.bias  module.requres_grad :  False
# name :  layer2.2.conv1.weight  module.requres_grad :  False
# name :  layer2.2.bn1.weight  module.requres_grad :  False
# name :  layer2.2.bn1.bias  module.requres_grad :  False
# name :  layer2.2.conv2.weight  module.requres_grad :  False
# name :  layer2.2.bn2.weight  module.requres_grad :  False
# name :  layer2.2.bn2.bias  module.requres_grad :  False
# name :  layer2.3.conv1.weight  module.requres_grad :  False
# name :  layer2.3.bn1.weight  module.requres_grad :  False
# name :  layer2.3.bn1.bias  module.requres_grad :  False
# name :  layer2.3.conv2.weight  module.requres_grad :  False
# name :  layer2.3.bn2.weight  module.requres_grad :  False
# name :  layer2.3.bn2.bias  module.requres_grad :  False
# name :  layer3.0.conv1.weight  module.requres_grad :  False
# name :  layer3.0.bn1.weight  module.requres_grad :  False
# name :  layer3.0.bn1.bias  module.requres_grad :  False
# name :  layer3.0.conv2.weight  module.requres_grad :  False
# name :  layer3.0.bn2.weight  module.requres_grad :  False
# name :  layer3.0.bn2.bias  module.requres_grad :  False
# name :  layer3.0.downsample.0.weight  module.requres_grad :  False
# name :  layer3.0.downsample.1.weight  module.requres_grad :  False
# name :  layer3.0.downsample.1.bias  module.requres_grad :  False
# name :  layer3.1.conv1.weight  module.requres_grad :  False
# name :  layer3.1.bn1.weight  module.requres_grad :  False
# name :  layer3.1.bn1.bias  module.requres_grad :  False
# name :  layer3.1.conv2.weight  module.requres_grad :  False
# name :  layer3.1.bn2.weight  module.requres_grad :  False
# name :  layer3.1.bn2.bias  module.requres_grad :  False
# name :  layer3.2.conv1.weight  module.requres_grad :  False
# name :  layer3.2.bn1.weight  module.requres_grad :  False
# name :  layer3.2.bn1.bias  module.requres_grad :  False
# name :  layer3.2.conv2.weight  module.requres_grad :  False
# name :  layer3.2.bn2.weight  module.requres_grad :  False
# name :  layer3.2.bn2.bias  module.requres_grad :  False
# name :  layer3.3.conv1.weight  module.requres_grad :  False
# name :  layer3.3.bn1.weight  module.requres_grad :  False
# name :  layer3.3.bn1.bias  module.requres_grad :  False
# name :  layer3.3.conv2.weight  module.requres_grad :  False
# name :  layer3.3.bn2.weight  module.requres_grad :  False
# name :  layer3.3.bn2.bias  module.requres_grad :  False
# name :  layer3.4.conv1.weight  module.requres_grad :  False
# name :  layer3.4.bn1.weight  module.requres_grad :  False
# name :  layer3.4.bn1.bias  module.requres_grad :  False
# name :  layer3.4.conv2.weight  module.requres_grad :  False
# name :  layer3.4.bn2.weight  module.requres_grad :  False
# name :  layer3.4.bn2.bias  module.requres_grad :  False
# name :  layer3.5.conv1.weight  module.requres_grad :  False
# name :  layer3.5.bn1.weight  module.requres_grad :  False
# name :  layer3.5.bn1.bias  module.requres_grad :  False
# name :  layer3.5.conv2.weight  module.requres_grad :  False
# name :  layer3.5.bn2.weight  module.requres_grad :  False
# name :  layer3.5.bn2.bias  module.requres_grad :  False
# name :  layer4.0.conv1.weight  module.requres_grad :  False
# name :  layer4.0.bn1.weight  module.requres_grad :  False
# name :  layer4.0.bn1.bias  module.requres_grad :  False
# name :  layer4.0.conv2.weight  module.requres_grad :  False
# name :  layer4.0.bn2.weight  module.requres_grad :  False
# name :  layer4.0.bn2.bias  module.requres_grad :  False
# name :  layer4.0.downsample.0.weight  module.requres_grad :  False
# name :  layer4.0.downsample.1.weight  module.requres_grad :  False
# name :  layer4.0.downsample.1.bias  module.requres_grad :  False
# name :  layer4.1.conv1.weight  module.requres_grad :  False
# name :  layer4.1.bn1.weight  module.requres_grad :  False
# name :  layer4.1.bn1.bias  module.requres_grad :  False
# name :  layer4.1.conv2.weight  module.requres_grad :  False
# name :  layer4.1.bn2.weight  module.requres_grad :  False
# name :  layer4.1.bn2.bias  module.requres_grad :  False
# name :  layer4.2.conv1.weight  module.requres_grad :  False
# name :  layer4.2.bn1.weight  module.requres_grad :  False
# name :  layer4.2.bn1.bias  module.requres_grad :  False
# name :  layer4.2.conv2.weight  module.requres_grad :  False
# name :  layer4.2.bn2.weight  module.requres_grad :  False
# name :  layer4.2.bn2.bias  module.requres_grad :  False
# name :  fc.weight  module.requres_grad :  True
# name :  fc.bias  module.requres_grad :  True

# %%
# fc만 True
# 나머지는 동결 (False)

# %%
optim = optim.Adam(model.parameters(),lr=1e-4)
model.to(device)
start_time =time.time()

# 학습 모드
# model.train()

for epoch in range(50):
  for data, labels in train_loader:

    optim.zero_grad()
    preds = model(data.to(device))
    loss = nn.CrossEntropyLoss()(preds,labels.to(device))
    loss.backward()

    optim.step()
  print("epoch : ",epoch+1, " loss : ", loss.item())
# Out:
# epoch :  1  loss :  0.9685714840888977
# epoch :  2  loss :  1.101059913635254
# epoch :  3  loss :  0.8869641423225403
# epoch :  4  loss :  0.8012635111808777
# epoch :  5  loss :  1.1779391765594482
# epoch :  6  loss :  0.8961995244026184
# epoch :  7  loss :  1.242013692855835
# epoch :  8  loss :  0.992055356502533
# epoch :  9  loss :  1.0167285203933716
# epoch :  10  loss :  0.9718274474143982
# epoch :  11  loss :  0.840205192565918
# epoch :  12  loss :  0.8304956555366516
# epoch :  13  loss :  0.6516799926757812
# epoch :  14  loss :  0.8943381309509277
# epoch :  15  loss :  0.7861774563789368
# epoch :  16  loss :  0.6261732578277588
# epoch :  17  loss :  0.7799389958381653
# epoch :  18  loss :  0.5556504130363464
# epoch :  19  loss :  0.5810002684593201
# epoch :  20  loss :  1.184378743171692
# epoch :  21  loss :  0.4700993597507477
# epoch :  22  loss :  1.1646231412887573
# epoch :  23  loss :  0.9650694727897644
# epoch :  24  loss :  0.6778871417045593
# epoch :  25  loss :  0.43939757347106934
# epoch :  26  loss :  0.5260447859764099
# epoch :  27  loss :  1.1171890497207642
# epoch :  28  loss :  0.7702304720878601
# epoch :  29  loss :  0.5359317660331726
# epoch :  30  loss :  0.7981829047203064
# epoch :  31  loss :  0.9406790137290955
# epoch :  32  loss :  0.5404428839683533
# epoch :  33  loss :  0.6873407959938049
# epoch :  34  loss :  0.6542174220085144
# epoch :  35  loss :  0.5344629883766174
# epoch :  36  loss :  0.5798133611679077
# epoch :  37  loss :  0.41121819615364075
# epoch :  38  loss :  0.564284086227417
# epoch :  39  loss :  0.8202826976776123
# epoch :  40  loss :  0.4396151006221771
# epoch :  41  loss :  0.6491748690605164
# epoch :  42  loss :  0.6183367371559143
# epoch :  43  loss :  0.6467497944831848
# epoch :  44  loss :  0.48338770866394043
# epoch :  45  loss :  0.4214645326137543
# epoch :  46  loss :  0.4752596914768219
# epoch :  47  loss :  0.13448648154735565
# epoch :  48  loss :  0.5682685971260071
# epoch :  49  loss :  0.3604777157306671
# epoch :  50  loss :  0.22949688136577606

# %%
# 모델에 dropout, normalize 적용 안되게함
model.eval()

corr = 0
with torch.no_grad():
  for data, labels in test_loader:
    preds = model(data.to(device))
    pred = torch.max(preds,1)[1]
    corr += torch.sum(pred==labels.to(device).data)

    print(f'예측결과 : {class_names[pred[0]]}  실제정답 : {class_names[labels.data[0]]}')
    # 출력하기 위해 data를 다시 cpu로
    imshow(data.cpu().data[0],title=class_names[pred[0]])
  acc = corr / len(test_datasets)
  print("acc : ",acc)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
