# %% [markdown]
# # Canny Edge : 차선 검출 등

# %% [markdown]
# #### 이미지의 특징을 추출함
# #### 노이즈가 있을 시 노이즈를 특징으로 잡을 수 있음 => 가우시안블러 사용
# #### 속도는 느림

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
src = cv2.imread('/content/drive/MyDrive/메타버스_아카데미_2기/딥러닝/7월/data/galaxy-soho.jpg')
cv2_imshow(src)
# Out:
# <PIL.Image.Image image mode=RGB size=640x365 at 0x7D288CB7B310>

# %%
# Edge 값만 찾아줌
dst = cv2.Canny(src,50,150)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=L size=640x365 at 0x7D285C83D2D0>

# %% [markdown]
# ### 허프 변환

# %% [markdown]
# #### 허프 변환 : Canny Edge의 직선 검출

# %%
src = cv2.imread('/content/drive/MyDrive/메타버스_아카데미_2기/딥러닝/7월/data/building.jpg')
cv2_imshow(src)
# Out:
# <PIL.Image.Image image mode=RGB size=868x600 at 0x7D288CB7BDF0>

# %%
src = cv2.imread('/content/drive/MyDrive/메타버스_아카데미_2기/딥러닝/7월/data/building.jpg')
# Canny 적용
edges = cv2.Canny(src,50,150)
cv2_imshow(edges)
# Out:
# <PIL.Image.Image image mode=L size=868x600 at 0x7D288D7BFB20>

# %%
import numpy as np

src = cv2.imread('/content/drive/MyDrive/메타버스_아카데미_2기/딥러닝/7월/data/building.jpg')
# Canny 적용
edges = cv2.Canny(src,50,150)

lines = cv2.HoughLinesP(edges,1.0,np.pi/180,160,minLineLength=50,maxLineGap=5)
dst = cv2.cvtColor(edges,cv2.COLOR_GRAY2BGR)

# lines = [[시작점x,시작점y,끝점x,끝점y]]
for tmp in range(lines.shape[0]):

  # 시작점
  pt1 = (lines[tmp][0][0],lines[tmp][0][1])
  pt2 = (lines[tmp][0][2],lines[tmp][0][3])

  cv2.line(dst,pt1,pt2,(0,0,255),2,cv2.LINE_AA)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=868x600 at 0x7D285C83DE40>

# %% [markdown]
# ### 영상의 이진화 (Binarization)

# %%
src = cv2.imread('/content/drive/MyDrive/메타버스_아카데미_2기/딥러닝/7월/data/aircraft.jpg')
cv2_imshow(src)
# Out:
# <PIL.Image.Image image mode=RGB size=640x453 at 0x7D285C83CF70>

# %%
src = cv2.imread('/content/drive/MyDrive/메타버스_아카데미_2기/딥러닝/7월/data/aircraft.jpg')
# 130~255 or 200~255 등으로 사용
_, dst = cv2.threshold(src,130,255,cv2.THRESH_BINARY)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=640x453 at 0x7D285C83F820>

# %%
_, dst = cv2.threshold(src,100,255,cv2.THRESH_BINARY)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=640x453 at 0x7D285C83F250>
