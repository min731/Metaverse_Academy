# %% [markdown]
# ### 인공신경망 기초

# %%
import sys

sys.version
# Out:
# '3.10.12 (main, Jun  7 2023, 12:45:35) [GCC 9.4.0]'

# %%
# self-supervised learning
# 모델 스스로 라벨링해서 학습하는 방법

# %%
# 머신러닝
# 경사하강법을 통해 미분 = 0 인 값을 찾는다
# 경사하강법
# https://www.robotstory.co.kr/raspberry/?vid=63

# 딥러닝도 마찬가지

# %%
# 딥러닝

# 퍼셉트론
# 뉴런(노드) + 엣지(파라미터)

# x1  -- w1 --
# x2  -- w2 --    y (bias)
# x3  -- w3 --
# (노드에서 노드로 진행될 때마다 미분값을 저장함)
# (이 때문에 메모리가 많이 필요함)

# z = x1*w1 + x2w2 + x3*w3 + y
# y = 시그마(z)
# 최종 y 값
# (단 계산이 틀렸을 때 역전파)

# 활성화 함수 : 선형으로 구분하지 못하는 데이터를 , 비선형으로 그려 구분할 수 있음 (더욱 고차원으로)
# 시그마(x)
# ex) 시그모이드

# 활성화 함수가 꼭 들어감
# 활성화 함수 : 데이터를 풍성하게 만듬

# %%
# 순전파
# Inputs(데이터) => Hidden Layers(파라미터) => Outputs(Y)

# 역전파 (딥러닝의 꽃)
# (y-y^)^2 오차값을 다시 거꾸로 전파시켜 가중치를 바꿈
# Chain Rule을 통해 계산
# 노드에 전부 미분값을 저장해 둔다

# %%
# 최적화 기법
# Optimazation

# 경사 하강법 (Gradient Descent)
# SGD
# Momentum : 경사가 급하면 천천히 내려감, 경사가 완만하면 빠르게 내려감
# Adam : 가장 많이쓰는 최적화 함수

# %%
# 손실 함수 (Loss Function)

# 예측값과 실제값이 얼마나 다른지
# MAE, MSE, RMSE
# MSE => RMSE : 값이 너무 클 수 있어 루트 씌워서 사용함
# 경험에 의해 MSE,RMSE 등 쓰면

# %%
# VGG16 : 레이어16개 , VGG8 : 레이어8개
# 딥러닝에서 레이어를 깊게 쌓으면 잘 맞힌다.하지만 과적합되거나 모델이 무거워 질 수 있다. 모델의 경량화가 필요할 수 있다.

# %%
# 머신러닝에서 배운 분류, 회귀, 군집화 모두 딥러닝에서 구현할 수 있음

# ex) 마트 매출 예측
# 노드(피처 or 변수) : 평수 , 층수, 가까운 아파트 단지 거리 등..
# Hidden Layers : (중간의 신경망을 어떻게 쌓아야 하는지 고민해야함), (아무렇게나 쌓아도 알아서 계산해줌) , 단 최적화하는 기법들은 있다
# y(예측하고자 하는 결과 값) : 가격

# %% [markdown]
# ### Cuda 설치

# %%
# 미니콘다, 텐서, 파이토치
# 에디터는 파이참

# cuda, CuDNN => 텐서플로우 기준으로 맞춤

# %%
# 파이참 설치

# New Project
# 가상환경 설치 : Previsouly configured Interpreter - Conda (C:miniconda3\condabin\conda.bat) - Create new environment (새 가상 환경, python 3.7 많이씀, 최신버전은 3.11)
# Tensorflow 설치 (https://www.tensorflow.org/install?hl=ko) (https://www.tensorflow.org/install/pip?hl=ko)

# 그래픽 카드에 맞는 NVDIA 드라이버 설

# Cuda 설치
# https://developer.nvidia.com/cuda-toolkit-archive
# Cuda 11.2 (Windows10) or 11.8 (Windows11)

# CuDNN 설치
# Download cuDNN v8.1.1 (Feburary 26th, 2021), for CUDA 11.0,11.1 and 11.2
# CuDNN 8.1.1

# 터미널
# conda install -c conda-forge cudatoolkit=11.8 cudnn=8.1.0
# pip install "tensorflow<2.11"

# import tensorflow as tf
# print(tf.config.list_physical_devices('GPU'))

# 우클릭 RUn - Main
# 이후 Shift + F10

# 파이토치 설치
# pip install torch==1.7.1+cu110 torchvision==0.8.2+cu110 -f https://download.pytorch.org/whl/torch_stable.html

# import  torch
# print(torch.cuda.is_available())

# import torch
# device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# print(device)

# CPU or GPU 어디에 쓰는지에 따라 다름
