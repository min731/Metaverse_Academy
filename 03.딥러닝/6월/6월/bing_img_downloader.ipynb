# %%
# !git clone https://github.com/ndb796/bing_image_downloader
# Out:
# Cloning into 'bing_image_downloader'...

# %%
import os
import shutil
from bing_image_downloader.bing_image_downloader import downloader

downloader.download('1920x1080 actress', limit=200,  output_dir='./1920x1080 faces', adult_filter_off=True, force_replace=False, timeout=60)
# Out:
# [Info] Indexing page: 1
# [Info] Indexed 35 Images on Page 1.
# ...
# #1 이미지 다운로드 (https://hdqwalls.com/download/1/aksha-actress-1920x1080.jpg)
# #1 파일 다운로드가 완료되었습니다.
# #2 이미지 다운로드 (https://images.wallpapersden.com/image/download/sexy-disha-patani-indian-actress_amxraGiUmZqaraWkpJRmbmdlrWZlbWU.jpg)
# #2 파일 다운로드가 완료되었습니다.
# #3 이미지 다운로드 (http://getwallpapers.com/wallpaper/full/c/6/8/1072089-latest-bollywood-actress-wallpapers-2018-hd-1920x1080-ipad.jpg)
# #3 파일 다운로드가 완료되었습니다.
# #4 이미지 다운로드 (https://cdn.wallpapersafari.com/12/92/af3psr.jpg)
# #4 파일 다운로드가 완료되었습니다.
# #5 이미지 다운로드 (https://wallpapercave.com/wp/wp2550710.jpg)
# #5 파일 다운로드가 완료되었습니다.
# #6 이미지 다운로드 (https://wallpaperaccess.com/full/683987.jpg)
# #6 파일 다운로드가 완료되었습니다.
# #7 이미지 다운로드 (https://wallpaperaccess.com/full/320133.jpg)
# #7 파일 다운로드가 완료되었습니다.
# #8 이미지 다운로드 (https://images.wallpapersden.com/image/download/canadian-actress-nina-dobrev-make-up_am1taGuUmZqaraWkpJRmbmdlrWZlbWU.jpg)
# #8 파일 다운로드가 완료되었습니다.
# ...
